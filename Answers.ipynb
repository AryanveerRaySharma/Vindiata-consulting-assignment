# %%
import pandas as pd

file_path = '/content/Answers/Playerwise Data for given dates .xlsx'
df = pd.read_excel(file_path)
df
# Out:
#                  Unnamed: 0    Unnamed: 1               Unnamed: 2  \
# 0    a. 2nd October Slot S1           NaN  b. 16th October Slot S2
# 1                   User ID  Total Points                  User ID
# 2                       634      1478.354                      634
# 3                       672          1300                      212
# 4                       566      1250.406                       99
# ..                      ...           ...                      ...
# 636                      75           0.2                      NaN
# 637                      59           0.2                      NaN
# 638                      46           0.2                      NaN
# 639                      41           0.2                      NaN
# 640                      19           0.2                      NaN
#
#        Unnamed: 3               Unnamed: 4    Unnamed: 5  \
# 0             NaN  c. 18th October Slot S1           NaN
# ...

# %%
import pandas as pd
file_path = '/content/Answers/Top 50 Players.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#      Unnamed: 0    Unnamed: 1           Unnamed: 2
# 0       User ID  Total Points  No. of Games Played
# 1            84    957776.094                  244
# 2           485    422184.489                   75
# 3           816     79504.275                   49
# 4           698     21791.804                   24
# ...         ...           ...                  ...
# 996          70          0.27                    1
# 997          51         0.206                    1
# 998          25         0.206                    1
# 999          56         0.205                    1
# 1000         38           0.2                    1
#
# [1001 rows x 3 columns]

# %%
import pandas as pd

file_path = '/content/Answers/Average Player Deposit.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#     Unnamed: 0                                Unnamed: 1
# 0      User ID  Average amount Deposited in October,2022
# 1          999                                      3000
# 2          998                                      1480
# 3          996                               3109.677419
# 4          995                                      6900
# ..         ...                                       ...
# 911          5                               1105.970149
# 912          4                                      1750
# 913          3                                     10000
# 914          2                                     28350
# 915          1                                      5000
#
# [916 rows x 2 columns]

# %%
import pandas as pd
file_path = '/content/Answers/Average games played per user.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#                                             Unnamed: 0           Unnamed: 1
# 0    Below is the Data of Gameplays in October with...                  NaN
# 1                                              User Id  Gameplays per month
# 2                                                  999                  174
# 3                                                  998                    4
# 4                                                  997                  109
# ..                                                 ...                  ...
# 882                                                  4                    5
# 883                                                  3                   80
# 884                                                  2                   97
# 885                                                  1                    8
# 886                                                  0                   15
#
# [887 rows x 2 columns]

# %%
import pandas as pd

file_path = '/content/Answers/Bonus for each winner.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#    User ID  Total Points  No. of Games Played  \
# 0       84    957776.094                  244
# 1      485    422184.489                   75
# 2      816     79504.275                   49
# 3      698     21791.804                   24
# 4      277     19269.015                   96
# 5      603     18655.175                    9
# 6      761     17636.091                    6
# 7      737     16810.700                   33
# 8      112     13290.603                    3
# 9      531     13029.305                   68
# 10     701     12983.247                   46
# 11     287     12866.805                   84
# 12     606     12713.900                  368
# 13     563     12374.231                   21
# 14     175     11654.604                   33
# 15     404     10831.346                    5
# 16     110     10626.801                   59
# 17     576     10327.413                  137
# 18     922     10250.368                 2838
# ...
