# %% [markdown]
# **Part A**
# 1. Playerwise loyalty points collected on the following timeperiods:
# a.2nd oct S1
# b.16th oct S2
# c.18th oct S1
# d.26nd oct S2

# %%
import pandas as pd

file_path = '/content/Vindiata assignment/Playerwise Data for given dates.xlsx'
df = pd.read_excel(file_path)
df
# Out:
#                  Unnamed: 0    Unnamed: 1               Unnamed: 2  \
# 0    a. 2nd October Slot S1           NaN  b. 16th October Slot S2
# 1                   User ID  Total Points                  User ID
# 2                       634      1478.354                      634
# 3                       672          1300                      212
# 4                       566      1250.406                       99
# ..                      ...           ...                      ...
# 636                      75           0.2                      NaN
# 637                      59           0.2                      NaN
# 638                      46           0.2                      NaN
# 639                      41           0.2                      NaN
# 640                      19           0.2                      NaN
#
#        Unnamed: 3               Unnamed: 4    Unnamed: 5  \
# 0             NaN  c. 18th October Slot S1           NaN
# ...
